# %% [markdown]
# <a href="https://colab.research.google.com/github/Komal-londhe/NLP_SentimentAnalysis/blob/main/NLP_Project_Narratives_Transformers_new.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Standard libraries for data analysis:   
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.stats import norm, skew
from scipy import stats
import statsmodels.api as sm
import pandas.util.testing as tm
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
example1 = "/content/Narratives.txt"
file1 = open(example1).read().split('"\n"')

# %%
list1 = file1[:100]
list1
# Out:
# ['"This is in reference to case number XXXX. This case was summarily closed as being a duplicate. In actuality it was attempt to clarify the erroneous result of the investigation. \n\nPlease consider the following : Attn : CFPB, XXXX XXXX Thank for the time and effort you have given to my situation. \n\nA. The matter regarding credit for {$5000.00} for a charge made to XXXX B. The matter regarding credit for {$2800.00} for a charge made to XXXX a. The result of your review is based on your misunderstanding of the timeline and coincidence of the amount and reason ( s ) for disputes. \nRecognize there were XXXX separate charges for {$5000.00} in close to one another. The first was to XXXX ; transaction XXXX and the other to someone from XXXX XXXX, XXXX, NV : transaction XXXX. \nI called in a dispute in XXXX. 2016 for the transaction XXXX in the amount of {$5000.00} by someone in XXXX NV. I did not make this charge. As you can see by the foreign fees I was in XXXX. Yes when noticed this
# ...

# %%
# !pip install transformers

# %%
from transformers import pipeline
summarizer = pipeline("summarization")
summarylist = summarizer(list1, truncation = True)
summarylist
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 (https://huggingface.co/sshleifer/distilbart-cnn-12-6)
# Your max_length is set to 142, but you input_length is only 103. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=51)
# Your max_length is set to 142, but you input_length is only 128. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=64)
# Your max_length is set to 142, but you input_length is only 128. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=64)
# ...

# %%
# Allocate a pipeline for sentiment-analysis
sentiment_analyzer = pipeline('sentiment-analysis')
sentimentlist = []
for i in range(len(summarylist)):
  sents = sentiment_analyzer(str(summarylist[i]), truncation = True)
  sentimentlist.append(sents)

sentimentlist
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english)
# Downloading:   0%|          | 0.00/629 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/255M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# [[{'label': 'NEGATIVE', 'score': 0.9995418787002563}],
#  [{'label': 'NEGATIVE', 'score': 0.9990741014480591}],
#  [{'label': 'NEGATIVE', 'score': 0.999708354473114}],
#  [{'label': 'NEGATIVE', 'score': 0.9979047775268555}],
#  [{'label': 'NEGATIVE', 'score': 0.9997090697288513}],
#  [{'label': 'NEGATIVE', 'score': 0.9977121353149414}],
#  [{'label': 'NEGATIVE', 'score': 0.995617151260376}],
#  [{'label': 'NEGATIVE', 'score': 0.9986165761947632}],
#  [{'label': 'NEGATIVE', 'score': 0.9991600513458252}],
#  [{'label': 'NEGATIVE', 'score': 0.9996236562728882}],
# ...

# %%
# Intent Classification
intent_classifier=pipeline("zero-shot-classification")
labels=['Quit Services','Functionality Concern','Security Concern','Overcharged','Not Benefited']
intentlist = []
for i in range(len(summarylist)):
    intent = intent_classifier(str(summarylist[i]), labels)
    intentlist.append(intent)

intentlist
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli (https://huggingface.co/facebook/bart-large-mnli)
# [{'labels': ['Quit Services',
#    'Functionality Concern',
#    'Overcharged',
#    'Not Benefited',
#    'Security Concern'],
#   'scores': [0.274722158908844,
#    0.22691619396209717,
#    0.20020093023777008,
#    0.15680624544620514,
#    0.14135442674160004],
#   'sequence': "{'summary_text': ' The result of your review is based on your misunderstanding of the timeline and coincidence of the amount and reason ( s ) for disputes . The charge for {$2800.00}, transaction XXXX to XXXX was mentioned in the initial case submitted through CFPB . This is a charge that also represents the payment made to this failed company . XXXX has been shut down for fraud by the government and has gravely impacted its members due non-access to products and services and the internet marketing system .'}"},
#  {'labels': ['Security Concern',
#    'Functionality Concern',
# ...

# %%
# emotion analysis
emotion_classifier=pipeline("zero-shot-classification", model="facebook/bart-large-mnli")
labels=['happy', 'angry', 'excited','sad', 'fearful','indifferent']
emotionlist = []
for i in range(len(summarylist)):
    emotion = emotion_classifier(str(summarylist[i]), labels)
    emotionlist.append(emotion)

emotionlist
# Out:
# Downloading:   0%|          | 0.00/1.13k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.52G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]
# [{'labels': ['fearful', 'sad', 'angry', 'excited', 'indifferent', 'happy'],
#   'scores': [0.3531888723373413,
#    0.26421332359313965,
#    0.16016362607479095,
#    0.134505033493042,
#    0.05244358628988266,
#    0.03548557683825493],
# ...

# %%
summaryData = pd.DataFrame(summarylist)
summaryData
# Out:
#                                          summary_text
# 0    The result of your review is based on your mi...
# 1    I was on a business trip in XXXX, my co worke...
# 2    "I applied for the Chase Freedom Account onli...
# 3    A check was issued by Barclays Bank Delaware ...
# 4    A woman ordered some clothing online, two pur...
# ..                                                ...
# 95   American Express reduced my credit limit from...
# 96   Netspend Fraud - XX/XX/2020 ( XXXX XXXX ) I b...
# 97   Military Star is in violation of the FRCA . C...
# 98   Discover has added additional security questi...
# 99   Chase Sapphire card ends in XXXX, XXXX . In X...
#
# [100 rows x 1 columns]

# %%
sentimentData = pd.DataFrame()
for i in range (len(sentimentlist)):
  data2 = pd.DataFrame(sentimentlist[i])
  sentimentData = sentimentData.append(data2)

sentimentData = sentimentData.reset_index(drop='True')
sentimentData
# Out:
#        label     score
# 0   NEGATIVE  0.999542
# 1   NEGATIVE  0.999074
# 2   NEGATIVE  0.999708
# 3   NEGATIVE  0.997905
# 4   NEGATIVE  0.999709
# ..       ...       ...
# 95  NEGATIVE  0.997850
# 96  NEGATIVE  0.999033
# 97  NEGATIVE  0.998858
# 98  NEGATIVE  0.995504
# 99  NEGATIVE  0.999732
#
# [100 rows x 2 columns]

# %%
sentimentData.rename(columns = {'label':'sentiment', 'score':'sentiment score'}, inplace=True)
sentimentData
# Out:
#    sentiment  sentiment score
# 0   NEGATIVE         0.999542
# 1   NEGATIVE         0.999074
# 2   NEGATIVE         0.999708
# 3   NEGATIVE         0.997905
# 4   NEGATIVE         0.999709
# ..       ...              ...
# 95  NEGATIVE         0.997850
# 96  NEGATIVE         0.999033
# 97  NEGATIVE         0.998858
# 98  NEGATIVE         0.995504
# 99  NEGATIVE         0.999732
#
# [100 rows x 2 columns]

# %%
intentData.rename(columns = {'labels':'intent', 'scores':'intent score'}, inplace=True)
intentData.drop(columns='sequence', inplace=True)
intentData
# Out:
#                    intent  intent score
# 0           Quit Services      0.274722
# 1        Security Concern      0.465241
# 2        Security Concern      0.528008
# 3        Security Concern      0.362701
# 4   Functionality Concern      0.286113
# ..                    ...           ...
# 95  Functionality Concern      0.392149
# 96       Security Concern      0.627050
# 97            Overcharged      0.710413
# 98       Security Concern      0.855783
# 99            Overcharged      0.560632
#
# [100 rows x 2 columns]

# %%
emotionsData.rename(columns = {'labels':'emotions', 'scores':'emotion score'}, inplace=True)
emotionsData.drop(columns='sequence', inplace=True)
emotionsData
# Out:
#    emotions  emotion score
# 0   fearful       0.353189
# 1   fearful       0.273816
# 2   fearful       0.407747
# 3   excited       0.292211
# 4     angry       0.434978
# ..      ...            ...
# 95    angry       0.238649
# 96  fearful       0.649366
# 97  fearful       0.410972
# 98  fearful       0.730934
# 99      sad       0.337843
#
# [100 rows x 2 columns]

# %%
datalist = [summaryData,sentimentData, intentData, emotionsData]
final_data = pd.concat(datalist, axis = 1)
final_data
# Out:
#                                          summary_text sentiment  \
# 0    The result of your review is based on your mi...  NEGATIVE
# 1    I was on a business trip in XXXX, my co worke...  NEGATIVE
# 2    "I applied for the Chase Freedom Account onli...  NEGATIVE
# 3    A check was issued by Barclays Bank Delaware ...  NEGATIVE
# 4    A woman ordered some clothing online, two pur...  NEGATIVE
# ..                                                ...       ...
# 95   American Express reduced my credit limit from...  NEGATIVE
# 96   Netspend Fraud - XX/XX/2020 ( XXXX XXXX ) I b...  NEGATIVE
# 97   Military Star is in violation of the FRCA . C...  NEGATIVE
# 98   Discover has added additional security questi...  NEGATIVE
# 99   Chase Sapphire card ends in XXXX, XXXX . In X...  NEGATIVE
#
#     sentiment score                 intent  intent score emotions  \
# 0          0.999542          Quit Services      0.274722  fearful
# ...

# %%
print("\n Distribution of sentiments : \n",final_data.sentiment.value_counts())
print("\n Distribution of intent : \n",final_data.intent.value_counts())
print("\n Distribution of emotions : \n",final_data.emotions.value_counts())
# Out:
#  Distribution of sentiments :
#  NEGATIVE    99
# POSITIVE     1
# Name: sentiment, dtype: int64
#
#  Distribution of intent :
#  Functionality Concern    35
# Overcharged              31
# Security Concern         21
# Not Benefited             8
# Quit Services             5
# Name: intent, dtype: int64
#
#  Distribution of emotions :
#  fearful        41
# angry          36
# excited        11
# sad             9
# indifferent     2
# happy           1
# Name: emotions, dtype: int64

# %%
final_data.to_csv('TransformerData.csv')
